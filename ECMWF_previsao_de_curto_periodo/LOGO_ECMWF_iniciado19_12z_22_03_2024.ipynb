# %%
import os

#https://data.ecmwf.int/forecasts/20240319/12z/ifs/0p25/oper/
pasta_atual = 'nc_19_03_24'
#pasta_atual = os.getcwd()
arquivos_ecmwf = os.listdir(pasta_atual)
arquivos_ecmwf2 = [arq for arq in arquivos_ecmwf if arq.endswith('.nc') ]
#print(arquivos_ecmwf2)

arquivos_ecmwf2.sort() 
print(arquivos_ecmwf2)
# Out:
# ['plotar20240319120000-066h-oper-fc.nc', 'plotar20240319120000-069h-oper-fc.nc', 'plotar20240319120000-072h-oper-fc.nc', 'plotar20240319120000-075h-oper-fc.nc', 'plotar20240319120000-078h-oper-fc.nc', 'plotar20240319120000-081h-oper-fc.nc', 'plotar20240319120000-084h-oper-fc.nc', 'plotar20240319120000-087h-oper-fc.nc', 'plotar20240319120000-090h-oper-fc.nc', 'plotar20240319120000-093h-oper-fc.nc', 'plotar20240319120000-096h-oper-fc.nc', 'plotar20240319120000-099h-oper-fc.nc', 'plotar20240319120000-102h-oper-fc.nc', 'plotar20240319120000-105h-oper-fc.nc', 'plotar20240319120000-108h-oper-fc.nc', 'plotar20240319120000-111h-oper-fc.nc', 'plotar20240319120000-114h-oper-fc.nc', 'plotar20240319120000-117h-oper-fc.nc', 'plotar20240319120000-120h-oper-fc.nc', 'plotar20240319120000-123h-oper-fc.nc', 'plotar20240319120000-126h-oper-fc.nc', 'plotar20240319120000-129h-oper-fc.nc', 'plotar20240319120000-132h-oper-fc.nc', 'plotar20240319120000-135h-oper-fc.nc', 'plotar20240319120000-138h-oper-fc.nc', 'plotar20240319120000-141h-oper-fc.nc', 'plotar20240319120000-144h-oper-fc.nc', 'plotar20240319120000-150h-oper-fc.nc', 'plotar20240319120000-156h-oper-fc.nc', 'plotar20240319120000-162h-oper-fc.nc', 'plotar20240319120000-168h-oper-fc.nc']

# %%
import xarray as xr


SOMA_EC= []
for arq_ec in arquivos_ecmwf2:
    EC = xr.open_mfdataset(os.path.join(pasta_atual,arq_ec), chunks={'time': 100})
    #print(ERA)
    print(arq_ec)
    chuva= EC['tp']*1000
    lista_data2= list(chuva.time.data)
    lista_data2= chuva.time.dt.strftime('%d-%m-%Y %H:%M:%S')
    lista_data2= list(lista_data2.data)
    print(lista_data2[0])

    chuva.plot()   
       
    SOMA_EC.append(chuva)

    
SOMA_EC= xr.concat(SOMA_EC, dim='Time')
# Out:
# C:\Users\fcasamento\AppData\Local\anaconda3\Lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# C:\Users\fcasamento\AppData\Local\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# plotar20240319120000-066h-oper-fc.nc
# 22-03-2024 06:00:00
# plotar20240319120000-069h-oper-fc.nc
# 22-03-2024 09:00:00
# plotar20240319120000-072h-oper-fc.nc
# 22-03-2024 12:00:00
# plotar20240319120000-075h-oper-fc.nc
# 22-03-2024 15:00:00
# plotar20240319120000-078h-oper-fc.nc
# 22-03-2024 18:00:00
# plotar20240319120000-081h-oper-fc.nc
# 22-03-2024 21:00:00
# plotar20240319120000-084h-oper-fc.nc
# 23-03-2024 00:00:00
# plotar20240319120000-087h-oper-fc.nc
# 23-03-2024 03:00:00
# plotar20240319120000-090h-oper-fc.nc
# 23-03-2024 06:00:00
# plotar20240319120000-093h-oper-fc.nc
# 23-03-2024 09:00:00
# plotar20240319120000-096h-oper-fc.nc
# 23-03-2024 12:00:00
# plotar20240319120000-099h-oper-fc.nc
# 23-03-2024 15:00:00
# plotar20240319120000-102h-oper-fc.nc
# 23-03-2024 18:00:00
# plotar20240319120000-105h-oper-fc.nc
# 23-03-2024 21:00:00
# plotar20240319120000-108h-oper-fc.nc
# 24-03-2024 00:00:00
# plotar20240319120000-111h-oper-fc.nc
# 24-03-2024 03:00:00
# plotar20240319120000-114h-oper-fc.nc
# 24-03-2024 06:00:00
# plotar20240319120000-117h-oper-fc.nc
# 24-03-2024 09:00:00
# plotar20240319120000-120h-oper-fc.nc
# 24-03-2024 12:00:00
# plotar20240319120000-123h-oper-fc.nc
# 24-03-2024 15:00:00
# plotar20240319120000-126h-oper-fc.nc
# 24-03-2024 18:00:00
# plotar20240319120000-129h-oper-fc.nc
# 24-03-2024 21:00:00
# plotar20240319120000-132h-oper-fc.nc
# 25-03-2024 00:00:00
# plotar20240319120000-135h-oper-fc.nc
# 25-03-2024 03:00:00
# plotar20240319120000-138h-oper-fc.nc
# 25-03-2024 06:00:00
# plotar20240319120000-141h-oper-fc.nc
# 25-03-2024 09:00:00
# plotar20240319120000-144h-oper-fc.nc
# 25-03-2024 12:00:00
# plotar20240319120000-150h-oper-fc.nc
# 25-03-2024 18:00:00
# plotar20240319120000-156h-oper-fc.nc
# 26-03-2024 00:00:00
# plotar20240319120000-162h-oper-fc.nc
# 26-03-2024 06:00:00
# plotar20240319120000-168h-oper-fc.nc
# 26-03-2024 12:00:00

# %%
arquivos_ecmwf2
# Out:
# ['plotar20240319120000-066h-oper-fc.nc',
#  'plotar20240319120000-069h-oper-fc.nc',
#  'plotar20240319120000-072h-oper-fc.nc',
#  'plotar20240319120000-075h-oper-fc.nc',
#  'plotar20240319120000-078h-oper-fc.nc',
#  'plotar20240319120000-081h-oper-fc.nc',
#  'plotar20240319120000-084h-oper-fc.nc',
#  'plotar20240319120000-087h-oper-fc.nc',
#  'plotar20240319120000-090h-oper-fc.nc',
#  'plotar20240319120000-093h-oper-fc.nc',
#  'plotar20240319120000-096h-oper-fc.nc',
#  'plotar20240319120000-099h-oper-fc.nc',
#  'plotar20240319120000-102h-oper-fc.nc',
#  'plotar20240319120000-105h-oper-fc.nc',
#  'plotar20240319120000-108h-oper-fc.nc',
#  'plotar20240319120000-111h-oper-fc.nc',
#  'plotar20240319120000-114h-oper-fc.nc',
#  'plotar20240319120000-117h-oper-fc.nc',
#  'plotar20240319120000-120h-oper-fc.nc',
#  'plotar20240319120000-123h-oper-fc.nc',
#  'plotar20240319120000-126h-oper-fc.nc',
#  'plotar20240319120000-129h-oper-fc.nc',
#  'plotar20240319120000-132h-oper-fc.nc',
#  'plotar20240319120000-135h-oper-fc.nc',
#  'plotar20240319120000-138h-oper-fc.nc',
#  'plotar20240319120000-141h-oper-fc.nc',
#  'plotar20240319120000-144h-oper-fc.nc',
#  'plotar20240319120000-150h-oper-fc.nc',
#  'plotar20240319120000-156h-oper-fc.nc',
#  'plotar20240319120000-162h-oper-fc.nc',
#  'plotar20240319120000-168h-oper-fc.nc']

# %%
SOMA_EC
# Out:
# <xarray.DataArray 'tp' (Time: 31, time: 31, lat: 721, lon: 1440)>
# dask.array<concatenate, shape=(31, 31, 721, 1440), dtype=float32, chunksize=(1, 31, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2024-03-22T06:00:00 ... 2024-03-26T12:00:00
#   * lon      (lon) float64 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
# Dimensions without coordinates: Time

# %%
#soma_prec = SOMA_EC.sum(dim='time')
#print("Soma da precipitação:", soma_prec)

# %%
soma_prec = SOMA_EC.sum(dim='Time')
print("Soma da precipitação:", soma_prec)
# Out:
# Soma da precipitação: <xarray.DataArray 'tp' (time: 31, lat: 721, lon: 1440)>
# dask.array<sum-aggregate, shape=(31, 721, 1440), dtype=float32, chunksize=(31, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2024-03-22T06:00:00 ... 2024-03-26T12:00:00
#   * lon      (lon) float64 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0

# %%
soma_prec
# Out:
# <xarray.DataArray 'tp' (time: 31, lat: 721, lon: 1440)>
# dask.array<sum-aggregate, shape=(31, 721, 1440), dtype=float32, chunksize=(31, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2024-03-22T06:00:00 ... 2024-03-26T12:00:00
#   * lon      (lon) float64 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0

# %%
#tem que colocar o último time, pois soma uma a um, então o 30 é  soma de todos os dados
print(len(arquivos_ecmwf2))
# Out:
# 31

# %%
soma_prec[30].plot()

# %%
ds_corte = soma_prec.sel(lat = slice(-19.5,-24), lon = slice(-47,-39))

# %%
ds_corte[30].plot()

# %%
ds_corte[-1].plot()

# %%
ds_corte
# Out:
# <xarray.DataArray 'tp' (time: 31, lat: 19, lon: 33)>
# dask.array<getitem, shape=(31, 19, 33), dtype=float32, chunksize=(31, 19, 33), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2024-03-22T06:00:00 ... 2024-03-26T12:00:00
#   * lon      (lon) float64 -47.0 -46.75 -46.5 -46.25 ... -39.5 -39.25 -39.0
#   * lat      (lat) float64 -19.5 -19.75 -20.0 -20.25 ... -23.5 -23.75 -24.0

# %%
lista_data2= list(SOMA_EC.time.data)
#print(lista_data2)
lista_data2= SOMA_EC.time.dt.strftime('%d-%m-%Y %H:%M:%S')
lista_data2= list(lista_data2.data)
print(lista_data2)
# Out:
# ['22-03-2024 06:00:00', '22-03-2024 09:00:00', '22-03-2024 12:00:00', '22-03-2024 15:00:00', '22-03-2024 18:00:00', '22-03-2024 21:00:00', '23-03-2024 00:00:00', '23-03-2024 03:00:00', '23-03-2024 06:00:00', '23-03-2024 09:00:00', '23-03-2024 12:00:00', '23-03-2024 15:00:00', '23-03-2024 18:00:00', '23-03-2024 21:00:00', '24-03-2024 00:00:00', '24-03-2024 03:00:00', '24-03-2024 06:00:00', '24-03-2024 09:00:00', '24-03-2024 12:00:00', '24-03-2024 15:00:00', '24-03-2024 18:00:00', '24-03-2024 21:00:00', '25-03-2024 00:00:00', '25-03-2024 03:00:00', '25-03-2024 06:00:00', '25-03-2024 09:00:00', '25-03-2024 12:00:00', '25-03-2024 18:00:00', '26-03-2024 00:00:00', '26-03-2024 06:00:00', '26-03-2024 12:00:00']

# %%
print(lista_data2[0])
print(f'{lista_data2[0][0:2]}/{lista_data2[0][3:5]} a {lista_data2[-1][0:2]}/{lista_data2[-1][3:5]}/{lista_data2[-1][6:10]} às {lista_data2[-1][-8:-3]}')
data_titulo= f'{lista_data2[0][0:2]}/{lista_data2[0][3:5]} a {lista_data2[-1][0:2]}/{lista_data2[-1][3:5]}/{lista_data2[-1][6:10]} às {lista_data2[-1][-8:-3]}UTC'
# Out:
# 22-03-2024 06:00:00
# 22/03 a 26/03/2024 às 12:00

# %%
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature
import cartopy.io.shapereader as shpreader  # Import shapefiles

# %%
# Assuming 'lat' and 'lon' are the dimension names, replace them with your actual dimension names
new_lon = np.linspace(ds_corte[30].lon[0], ds_corte[30].lon[-1], ds_corte[30].sizes["lon"] * 7)
new_lat = np.linspace(ds_corte[30].lat[0], ds_corte[30].lat[-1], ds_corte[30].sizes["lat"] * 7)

# Use dimension names instead of string indices
NEW_prec_total = ds_corte[30].interp(lat=new_lat, lon=new_lon)

# %%
NEW_prec_total
# Out:
# <xarray.DataArray 'tp' (lat: 133, lon: 231)>
# dask.array<chunked_aware_interpnd, shape=(133, 231), dtype=float32, chunksize=(133, 231), chunktype=numpy.ndarray>
# Coordinates:
#     time     datetime64[ns] 2024-03-26T12:00:00
#   * lat      (lat) float64 -19.5 -19.53 -19.57 -19.6 ... -23.93 -23.97 -24.0
#   * lon      (lon) float64 -47.0 -46.97 -46.93 -46.9 ... -39.07 -39.03 -39.0

# %%
# Configura o tamanho do plot
fig = plt.figure(figsize=(15, 10))

# Define a projeção
ax = plt.axes(projection=ccrs.PlateCarree())

# Adiciona linha de costa, terra, borda
ax.coastlines(resolution='10m', color='grey')
ax.add_feature(cartopy.feature.LAND, facecolor='silver')
ax.add_feature(cartopy.feature.BORDERS, edgecolor='gray')

# Define a área do plot
limites = [-47, -39, -24, -19.5]

ax.set_extent(limites, crs=ccrs.PlateCarree())

# Adjust the contour levels based on the data range
# Plot the image
img1 = ax.imshow(NEW_prec_total, origin='upper', extent=limites, vmin=0, vmax=700, cmap='jet') 

# Define contour levels
data_min = 0
data_max = 650
interval = 100
levels = np.arange(data_min, data_max, interval)

    
lons, lats = np.meshgrid(NEW_prec_total.lon, NEW_prec_total.lat)

#contorno havia ficado antes de ponta cabeça

# prec_total_mes[0][::-1, :] 
contour = ax.contour(lons, lats, NEW_prec_total, colors='white', linewidths=0.3, levels=levels, origin='upper')
ax.clabel(contour, inline=1, inline_spacing=0, fontsize=15, fmt='%1.0f', colors='black')

# Adicionando título
plt.title(f'Previsão de Chuva mm - {data_titulo}', fontweight='bold', loc='left')
plt.title('ECMWF', fontweight='bold', fontsize=8, loc='right')

# Adicionando os limites dos estados
shapefile_path = shpreader.natural_earth(resolution='10m', category='cultural', name='admin_1_states_provinces_lines')
shapefile = shpreader.Reader(shapefile_path).geometries()
ax.add_geometries(shapefile, ccrs.PlateCarree(), edgecolor='black', facecolor='none', linewidth=0.3)

shapefile = list(shpreader.Reader('../WRF_CPTEC/RJ_municipios/RJ_Municipios_2022.shp').geometries())
#https://www.ibge.gov.br/geociencias/organizacao-do-territorio/malhas-territoriais/15774-malhas.html

ax.add_geometries(shapefile, ccrs.PlateCarree(), edgecolor='darkred',facecolor='none', linewidth=1.5)

# Configuração das grades
gl = ax.gridlines(linestyle='--', xlocs=np.arange(-55, -38, 2), ylocs=np.arange(-30, -15, 0.5), draw_labels=True)
gl.top_labels = False
gl.right_labels = False


 # Adicionando a barra de cor
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
    

    

axins = inset_axes(ax, width="5%", height="100%", loc='right', borderpad=-5)
cbar = fig.colorbar(img1, cax=axins, orientation='vertical', label='Chuva (mm)', extend='both')
    
# North Arrow
ax.annotate(u'\u25B2 \nN ', ha='center', fontsize=25, xy=(-40, -20))
    
# Data box
box = dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3')
ax.annotate(data_titulo, ha='center', fontsize=12, xy=(-40, -23), bbox=box)
#------------------logo----------------------------
#plt.savefig(f'figuras_plot_cfsvw/chuva_cfs_modelo3{i}.png',bbox_inches='tight', dpi=100)
# Mostra o plot

im_log1 = plt.imread(("ecmwflogo.png"))
#MEXER NAS POSIÇÕES 1 = Y 2 = Y (menor mais para baixo), 3 X (maior mais para o lado)

newax = fig.add_axes([0.13,0.18,0.1,0.1], anchor='NE',zorder=0)
#newax = fig.add_axes([-0.1,0.5,0.5,0.3], anchor='NE', zorder=1)

newax.imshow(im_log1)
    
im_log2=plt.imread(("logo2.jpg"))

#MEXER NAS POSIÇÕES 1 = Y 2 = Y (menor mais para baixo), 3 X (maior mais para o lado)


newax1 = fig.add_axes([0.7,0.18,0.1,0.1], anchor='NE',zorder=0)

#newax1 = fig.add_axes([0.6,0.08,0.1,0.1], anchor='NE',zorder=0)
#newax = fig.add_axes([-0.1,0.5,0.5,0.3], anchor='NE', zorder=1)

newax1.imshow(im_log2)    
    
# plt.savefig(f'chuva_cfs_modelo3{j}.png',bbox_inches='tight', dpi=100)

#    
newax.axis('off') 
newax1.axis('off') 




#plt.savefig(f'Figuras_CFSV2_GRIB/chuva_cfs_modelo3_contorno{j}.png',bbox_inches='tight', dpi=100)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature
import cartopy.io.shapereader as shpreader
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Suponha que NEW_prec_total seja a sua matriz de dados de precipitação
# Encontrar o índice do valor máximo na matriz
max_value_index = np.unravel_index(np.argmax(NEW_prec_total.values), NEW_prec_total.shape)

# Extrair coordenadas (longitude e latitude) do valor máximo
max_lon = NEW_prec_total.lon[max_value_index[1]]
max_lat = NEW_prec_total.lat[max_value_index[0]]
max_precipitation = NEW_prec_total.values[max_value_index]

# Configura o tamanho do plot
fig = plt.figure(figsize=(15, 10))
ax = plt.axes(projection=ccrs.PlateCarree())

# Adiciona linha de costa, terra, borda
ax.coastlines(resolution='10m', color='grey')
ax.add_feature(cartopy.feature.LAND, facecolor='silver')
ax.add_feature(cartopy.feature.BORDERS, edgecolor='gray')

# Define a área do plot
limites = [-47, -39, -24, -19.5]
ax.set_extent(limites, crs=ccrs.PlateCarree())

# Plot a imagem da precipitação
img1 = ax.imshow(NEW_prec_total.values, origin='upper', extent=limites, vmin=0, vmax=700, cmap='jet')

# Plot os contornos da precipitação
contour = ax.contour(lons, lats, NEW_prec_total.values, colors='white', linewidths=0.3, levels=levels, origin='upper')
ax.clabel(contour, inline=1, inline_spacing=0, fontsize=15, fmt='%1.0f', colors='black')

# Adicionar marcador para o máximo
ax.plot(max_lon, max_lat, marker='o', color='red', markersize=5)

# Adicionar uma legenda para o marcador
ax.text(max_lon, max_lat, f'Máx:\n {max_precipitation:.1f}mm', color='black', fontweight='bold', fontsize=20, ha='right')

# Adiciona título
plt.title(f'Previsão de Chuva mm - {data_titulo}', fontweight='bold', loc='left')
plt.title('ECMWF IFS 0.25', fontweight='bold', fontsize=8, loc='right')

# Adiciona os limites dos estados
shapefile_path = shpreader.natural_earth(resolution='10m', category='cultural', name='admin_1_states_provinces_lines')
shapefile = shpreader.Reader(shapefile_path).geometries()
ax.add_geometries(shapefile, ccrs.PlateCarree(), edgecolor='black', facecolor='none', linewidth=0.3)

shapefile = list(shpreader.Reader('../WRF_CPTEC/RJ_municipios/RJ_Municipios_2022.shp').geometries())
ax.add_geometries(shapefile, ccrs.PlateCarree(), edgecolor='darkred', facecolor='none', linewidth=1.5)

# Configuração das grades
gl = ax.gridlines(linestyle='--', xlocs=np.arange(-55, -38, 2), ylocs=np.arange(-30, -15, 0.5), draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# Adiciona a barra de cor
axins = inset_axes(ax, width="5%", height="100%", loc='right', borderpad=-5)
cbar = fig.colorbar(img1, cax=axins, orientation='vertical', label='Chuva (mm)', extend='both')

# North Arrow
ax.annotate(u'\u25B2 \nN ', ha='center', fontsize=25, xy=(-40, -20))

# Data box
box = dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3')
ax.annotate(data_titulo, ha='center', fontsize=12, xy=(-40, -23), bbox=box)

# Adiciona logotipos
im_log1 = plt.imread(("ecmwflogo.png"))
newax = fig.add_axes([0.13, 0.18, 0.1, 0.1], anchor='NE', zorder=0)
newax.imshow(im_log1)

im_log2=plt.imread(("logo_ecmwf.png"))
newax1 = fig.add_axes([0.7, 0.18, 0.1, 0.1], anchor='NE', zorder=0)
newax1.imshow(im_log2)

# Desliga os eixos
newax.axis('off')
newax1.axis('off')

plt.show()

# %%
print((max_lon, max_lat, f'Máx: {max_precipitation}mm'))
# Out:
# (<xarray.DataArray 'lon' ()>
# array(-43.)
# Coordinates:
#     time     datetime64[ns] 2024-03-26T12:00:00
#     lon      float64 -43.0
# Attributes:
#     standard_name:  longitude
#     long_name:      longitude
#     units:          degrees_east
#     axis:           X, <xarray.DataArray 'lat' ()>
# array(-22.5)
# Coordinates:
#     time     datetime64[ns] 2024-03-26T12:00:00
#     lat      float64 -22.5
# Attributes:
#     standard_name:  latitude
#     long_name:      latitude
#     units:          degrees_north
#     axis:           Y, 'Máx: 602.783203125mm')

# %% [markdown]
# # Outra maneira de somar

# %%
#cálculo da chuva mensal, quero agrupar os dados, que vem horária
ds_mensal = SOMA_EC.groupby('time.month').sum(dim = 'time')
ds_mensal
# Out:
# <xarray.DataArray 'tp' (Time: 31, month: 1, lat: 721, lon: 1440)>
# dask.array<transpose, shape=(31, 1, 721, 1440), dtype=float32, chunksize=(1, 1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
#   * month    (month) int64 3
# Dimensions without coordinates: Time

# %%
ds_mensal[30]
# Out:
# <xarray.DataArray 'tp' (month: 1, lat: 721, lon: 1440)>
# dask.array<getitem, shape=(1, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 -180.0 -179.8 -179.5 -179.2 ... 179.2 179.5 179.8
#   * lat      (lat) float64 90.0 89.75 89.5 89.25 ... -89.25 -89.5 -89.75 -90.0
#   * month    (month) int64 3

# %%
ds_corte = ds_mensal.sel(lat = slice(-19.5,-24), lon = slice(-47,-39))

# %%
ds_corte
# Out:
# <xarray.DataArray 'tp' (Time: 31, month: 1, lat: 19, lon: 33)>
# dask.array<getitem, shape=(31, 1, 19, 33), dtype=float32, chunksize=(1, 1, 19, 33), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float64 -47.0 -46.75 -46.5 -46.25 ... -39.5 -39.25 -39.0
#   * lat      (lat) float64 -19.5 -19.75 -20.0 -20.25 ... -23.5 -23.75 -24.0
#   * month    (month) int64 3
# Dimensions without coordinates: Time

# %%
ds_corte[30].plot()

# %%
# Assuming 'lat' and 'lon' are the dimension names, replace them with your actual dimension names
new_lon = np.linspace(ds_corte[30].lon[0], ds_corte[30].lon[-1], ds_corte[30].sizes["lon"] * 7)
new_lat = np.linspace(ds_corte[30].lat[0], ds_corte[30].lat[-1], ds_corte[30].sizes["lat"] * 7)

# Use dimension names instead of string indices
NEW_prec_total = ds_corte[30].interp(lat=new_lat, lon=new_lon)

# %%
NEW_prec_total
# Out:
# <xarray.DataArray 'tp' (month: 1, lat: 133, lon: 231)>
# dask.array<chunked_aware_interpnd, shape=(1, 133, 231), dtype=float32, chunksize=(1, 133, 231), chunktype=numpy.ndarray>
# Coordinates:
#   * month    (month) int64 3
#   * lat      (lat) float64 -19.5 -19.53 -19.57 -19.6 ... -23.93 -23.97 -24.0
#   * lon      (lon) float64 -47.0 -46.97 -46.93 -46.9 ... -39.07 -39.03 -39.0

# %%
NEW_prec_total[0]
# Out:
# <xarray.DataArray 'tp' (lat: 133, lon: 231)>
# dask.array<getitem, shape=(133, 231), dtype=float32, chunksize=(133, 231), chunktype=numpy.ndarray>
# Coordinates:
#     month    int64 3
#   * lat      (lat) float64 -19.5 -19.53 -19.57 -19.6 ... -23.93 -23.97 -24.0
#   * lon      (lon) float64 -47.0 -46.97 -46.93 -46.9 ... -39.07 -39.03 -39.0

# %%
# Encontrar o índice do valor máximo na matriz
max_value_index = np.unravel_index(np.argmax(NEW_prec_total[0].values), NEW_prec_total[0].shape)

# Extrair coordenadas (longitude e latitude) do valor máximo
max_lon = NEW_prec_total[0].lon[max_value_index[1]]
max_lat = NEW_prec_total[0].lat[max_value_index[0]]
max_precipitation = NEW_prec_total[0].values[max_value_index]

# %%
max_precipitation
# Out:
# 602.783203125

# %%
# Configura o tamanho do plot
fig = plt.figure(figsize=(15, 10))

# Define a projeção
ax = plt.axes(projection=ccrs.PlateCarree())

# Adiciona linha de costa, terra, borda
ax.coastlines(resolution='10m', color='grey')
ax.add_feature(cartopy.feature.LAND, facecolor='silver')
ax.add_feature(cartopy.feature.BORDERS, edgecolor='gray')

# Define a área do plot
limites = [-47, -39, -24, -19.5]

ax.set_extent(limites, crs=ccrs.PlateCarree())

# Adjust the contour levels based on the data range
# Plot the image
#img1 = ax.imshow(NEW_prec_total[0], origin='lower', extent=limites, vmin=0, vmax=500, cmap='jet') 
img1 = ax.imshow(NEW_prec_total[0], origin='upper', extent=limites, vmin=0, vmax=700, cmap='jet') 

# Define contour levels
data_min = 0
data_max = 700
interval = 50
levels = np.arange(data_min, data_max, interval)

    
lons, lats = np.meshgrid(NEW_prec_total[0].lon, NEW_prec_total[0].lat)

#contorno havia ficado antes de ponta cabeça

# prec_total_mes[0][::-1, :] 

contour = ax.contour(lons, lats, NEW_prec_total[0], colors='white', linewidths=0.3, levels=levels, origin='lower')

#contour = ax.contour(lons, lats, NEW_prec_total[0][::-1, :], colors='white', linewidths=0.3, levels=levels, origin='lower')
ax.clabel(contour, inline=1, inline_spacing=0, fontsize=13, fmt='%1.0f', colors='black')


# Adicionar marcador para o máximo
#ax.plot(max_lon, max_lat, marker='o', color='red', markersize=5)

# Adicionar uma legenda para o marcador
ax.text(max_lon, max_lat, f'Máx:\n {max_precipitation:.1f}mm', color='black', fontweight='bold', fontsize=18, ha='right')



# Adicionando título
plt.title(f'Previsão de Chuva mm - {data_titulo}', fontweight='bold', loc='left')
plt.title('ECMWF IFS 0.25', fontweight='bold', fontsize=8, loc='right')

# Adicionando os limites dos estados
shapefile_path = shpreader.natural_earth(resolution='10m', category='cultural', name='admin_1_states_provinces_lines')
shapefile = shpreader.Reader(shapefile_path).geometries()
ax.add_geometries(shapefile, ccrs.PlateCarree(), edgecolor='black', facecolor='none', linewidth=0.3)

shapefile = list(shpreader.Reader('../WRF_CPTEC/RJ_municipios/RJ_Municipios_2022.shp').geometries())
#https://www.ibge.gov.br/geociencias/organizacao-do-territorio/malhas-territoriais/15774-malhas.html

ax.add_geometries(shapefile, ccrs.PlateCarree(), edgecolor='darkred',facecolor='none', linewidth=1.5)

# Configuração das grades
gl = ax.gridlines(linestyle='--', xlocs=np.arange(-55, -38, 1), ylocs=np.arange(-30, -15, 0.5), draw_labels=True)
gl.top_labels = False
gl.right_labels = False


 # Adicionando a barra de cor
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
    

    

axins = inset_axes(ax, width="5%", height="100%", loc='right', borderpad=-5)
cbar = fig.colorbar(img1, cax=axins, orientation='vertical', label='Chuva (mm)', extend='both')
    
# North Arrow
ax.annotate(u'\u25B2 \nN ', ha='center', fontsize=25, xy=(-40, -20))
    
# Data box
box = dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.3')
ax.annotate(data_titulo, ha='center', fontsize=12, xy=(-40.7, -23), bbox=box)
#------------------logo----------------------------
#plt.savefig(f'figuras_plot_cfsvw/chuva_cfs_modelo3{i}.png',bbox_inches='tight', dpi=100)
# Mostra o plot

#MEXER NAS POSIÇÕES 1 = Y 2 = Y (menor mais para baixo), 3 X (maior mais para o lado)

# Adiciona logotipos
im_log1 = plt.imread(("ecmwflogo.png"))
newax = fig.add_axes([0.13, 0.18, 0.1, 0.1], anchor='NE', zorder=0)
newax.imshow(im_log1)
    
#im_log2=plt.imread(("../WRF_CPTEC/logo-lentz.png"))
#MEXER NAS POSIÇÕES 1 = Y 2 = Y (menor mais para baixo), 3 X (maior mais para o lado)

im_log2=plt.imread(("logo_ecmwf.png"))
newax1 = fig.add_axes([0.7, 0.18, 0.1, 0.1], anchor='NE', zorder=0)
#newax = fig.add_axes([-0.1,0.5,0.5,0.3], anchor='NE', zorder=1)

newax1.imshow(im_log2)    
    
# plt.savefig(f'chuva_cfs_modelo3{j}.png',bbox_inches='tight', dpi=100)

#    
newax.axis('off') 
newax1.axis('off') 




#plt.savefig(f'Figuras_CFSV2_GRIB/chuva_cfs_modelo3_contorno{j}.png',bbox_inches='tight', dpi=100)

plt.show()

# %% [markdown]
# https://data.ecmwf.int/forecasts/20240321/00z/aifs/0p25/oper/

# %% [raw]
# https://confluence.ecmwf.int/pages/viewpage.action?pageId=197702790
# converter
#
# tp [mm]={tph [m]⋅1000
# (tph [m] − tph−1 [m]) ⋅1000h=01UTCotherwise

# %%
NEW_prec_total.plot()

# %%
#tirar o 00 utc, para criar a figura

# %% [markdown]
# https://data.ecmwf.int/forecasts/20240321/00z/aifs/0p25/oper/
